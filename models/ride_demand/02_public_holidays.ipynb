# %% [markdown]
# Source: <https://www.officeholidays.com/countries/usa/new-york/2024>

# %% [markdown]
# | Date | Holiday Name | Holiday Type |
# |------|--------------|--------------|
# | 01/01/2024 | New Year's Day | National |
# | 15/01/2024 | Martin Luther King Jr. Day | National |
# | 12/02/2024 | Lincoln's Birthday | Government |
# | 19/02/2024 | Washington's Birthday | Regional |
# | 31/03/2024 | Easter Sunday | Not a holiday |
# | 12/05/2024 | Mother's Day | Not a holiday |
# | 27/05/2024 | Memorial Day | National |
# | 16/06/2024 | Father's Day | Not a holiday |
# | 19/06/2024 | Juneteenth | Regional |
# | 04/07/2024 | Independence Day | National |
# | 02/09/2024 | Labor Day | National |
# | 14/10/2024 | Columbus Day | Regional |
# | 05/11/2024 | Election Day | Government |
# | 11/11/2024 | Veterans Day | Regional |
# | 28/11/2024 | Thanksgiving | National |
# | 25/12/2024 | Christmas Day | National |

# %%
import pandas as pd

data = {
    "date": [
        "01/01/2024", "15/01/2024", "12/02/2024", "19/02/2024",
        "31/03/2024", "12/05/2024", "27/05/2024", "16/06/2024",
        "19/06/2024", "04/07/2024", "02/09/2024", "14/10/2024",
        "05/11/2024", "11/11/2024", "28/11/2024", "25/12/2024"
    ],
    "holiday": [
        "New Year's Day", "Martin Luther King Jr. Day", "Lincoln's Birthday",
        "Washington's Birthday", "Easter Sunday", "Mother's Day",
        "Memorial Day", "Father's Day", "Juneteenth", "Independence Day",
        "Labor Day", "Columbus Day", "Election Day", "Veterans Day",
        "Thanksgiving", "Christmas Day"
    ],
    "holiday_type": [
        "National", "National", "Government", "Regional", "Not a holiday",
        "Not a holiday", "National", "Not a holiday", "Regional", "National",
        "National", "Regional", "Government", "Regional", "National", "National"
    ]
}

calendar = pd.DataFrame(data)
calendar["date"] = pd.to_datetime(calendar["date"], format="%d/%m/%Y")

print(calendar)
# Out:
#          date                     holiday           type
# 0  2024-01-01              New Year's Day       National
# 1  2024-01-15  Martin Luther King Jr. Day       National
# 2  2024-02-12          Lincoln's Birthday     Government
# 3  2024-02-19       Washington's Birthday       Regional
# 4  2024-03-31               Easter Sunday  Not a holiday
# 5  2024-05-12                Mother's Day  Not a holiday
# 6  2024-05-27                Memorial Day       National
# 7  2024-06-16                Father's Day  Not a holiday
# 8  2024-06-19                  Juneteenth       Regional
# 9  2024-07-04            Independence Day       National
# 10 2024-09-02                   Labor Day       National
# 11 2024-10-14                Columbus Day       Regional
# 12 2024-11-05                Election Day     Government
# 13 2024-11-11                Veterans Day       Regional
# 14 2024-11-28                Thanksgiving       National
# 15 2024-12-25               Christmas Day       National

# %%
import dataset

df = dataset.read_agg(month_start=1, month_end=12)
df.info()
# Out:
# /home/kv/education/ml/groupwork/models/ride_demand/dataset.py:276: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   wthr.replace('T', 0, inplace=True)
# /home/kv/education/ml/groupwork/models/ride_demand/dataset.py:277: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   wthr.replace('M', np.nan, inplace=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2887842 entries, 0 to 2887841
# Data columns (total 45 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   pickup_year            int32
#  1   pickup_month           int32
#  2   pickup_week            UInt32
#  3   pickup_day             int32
#  4   pickup_date            datetime64[ns]
#  5   pickup_dow             int32
#  6   pickup_service_zone    category
#  7   pickup_zone            object
#  8   dropoff_service_zone   category
#  9   dropoff_zone           object
#  10  route                  object
#  11  service_route          category
#  12  vendor                 object
#  13  total_ride_count       int64
#  14  total_passenger_count  float64
#  15  avg_passenger_count    float64
#  16  total_trip_distance    float64
#  17  avg_trip_distance      float64
#  18  total_fare_amount      float64
#  19  avg_fare_amount        float64
#  20  total_extra            float64
#  21  avg_extra              float64
#  22  total_mta_tax          float64
#  23  avg_mta_tax            float64
#  24  total_tip_amount       float64
#  25  avg_tip_amount         float64
#  26  total_tolls_amount     float64
#  27  avg_tolls_amount       float64
#  28  total_impr_surcharge   float64
#  29  avg_impr_surcharge     float64
#  30  total_revenue          float64
#  31  avg_revenue            float64
#  32  total_airport_fee      float64
#  33  avg_airport_fee        float64
#  34  temp_high              float64
#  35  precip                 float64
#  36  snow                   float64
#  37  max_wind_speed         float64
#  38  cloud_coverage         float64
#  39  fog                    object
#  40  low_vis                object
#  41  thunder                object
#  42  hail                   object
#  43  freezing_rain          object
#  44  haze                   object
# dtypes: UInt32(1), category(3), datetime64[ns](1), float64(25), int32(4), int64(1), object(10)
# memory usage: 881.3+ MB

# %%
df = pd.merge(df, calendar, left_on='pickup_date', right_on='date', how='left')
df['holiday'] = df['holiday'].fillna("None")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2887842 entries, 0 to 2887841
# Data columns (total 54 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   pickup_year            int32
#  1   pickup_month           int32
#  2   pickup_week            UInt32
#  3   pickup_day             int32
#  4   pickup_date            datetime64[ns]
#  5   pickup_dow             int32
#  6   pickup_service_zone    category
#  7   pickup_zone            object
#  8   dropoff_service_zone   category
#  9   dropoff_zone           object
#  10  route                  object
#  11  service_route          category
#  12  vendor                 object
#  13  total_ride_count       int64
#  14  total_passenger_count  float64
#  15  avg_passenger_count    float64
#  16  total_trip_distance    float64
#  17  avg_trip_distance      float64
#  18  total_fare_amount      float64
#  19  avg_fare_amount        float64
#  20  total_extra            float64
#  21  avg_extra              float64
#  22  total_mta_tax          float64
#  23  avg_mta_tax            float64
#  24  total_tip_amount       float64
#  25  avg_tip_amount         float64
#  26  total_tolls_amount     float64
#  27  avg_tolls_amount       float64
#  28  total_impr_surcharge   float64
#  29  avg_impr_surcharge     float64
#  30  total_revenue          float64
#  31  avg_revenue            float64
#  32  total_airport_fee      float64
#  33  avg_airport_fee        float64
#  34  temp_high              float64
#  35  precip                 float64
#  36  snow                   float64
#  37  max_wind_speed         float64
#  38  cloud_coverage         float64
#  39  fog                    object
#  40  low_vis                object
#  41  thunder                object
#  42  hail                   object
#  43  freezing_rain          object
#  44  haze                   object
#  45  date_x                 datetime64[ns]
#  46  holiday_x              object
#  47  type_x                 object
#  48  date_y                 datetime64[ns]
#  49  holiday_y              object
#  50  type_y                 object
#  51  date                   datetime64[ns]
#  52  holiday                object
#  53  type                   object
# dtypes: UInt32(1), category(3), datetime64[ns](4), float64(25), int32(4), int64(1), object(16)
# memory usage: 1.1+ GB

# %%
df[df['holiday'].notna()]
df['']
# Out:
#          pickup_year  pickup_month  pickup_week  pickup_day pickup_date  \
# 10              2024             1            1           1  2024-01-01
# 11              2024             1            1           1  2024-01-01
# 12              2024             1            1           1  2024-01-01
# 13              2024             1            1           1  2024-01-01
# 14              2024             1            1           1  2024-01-01
# ...              ...           ...          ...         ...         ...
# 2859437         2024            12           52          25  2024-12-25
# 2859438         2024            12           52          25  2024-12-25
# 2859439         2024            12           52          25  2024-12-25
# 2859440         2024            12           52          25  2024-12-25
# 2859441         2024            12           52          25  2024-12-25
#
#          pickup_dow pickup_service_zone     pickup_zone dropoff_service_zone  \
# 10                0           Boro Zone  Central Harlem             Airports
# 11                0           Boro Zone  Central Harlem             Airports
# 12                0           Boro Zone  Central Harlem            Boro Zone
# 13                0           Boro Zone  Central Harlem            Boro Zone
# 14                0           Boro Zone  Central Harlem            Boro Zone
# ...             ...                 ...             ...                  ...
# 2859437           2         Yellow Zone  Yorkville West          Yellow Zone
# 2859438           2         Yellow Zone  Yorkville West          Yellow Zone
# 2859439           2         Yellow Zone  Yorkville West          Yellow Zone
# 2859440           2         Yellow Zone  Yorkville West          Yellow Zone
# 2859441           2         Yellow Zone  Yorkville West          Yellow Zone
#
#                  dropoff_zone  ...   haze     date_x       holiday_x  \
# 10                JFK Airport  ...  False 2024-01-01  New Year's Day
# 11          LaGuardia Airport  ...  False 2024-01-01  New Year's Day
# 12             Central Harlem  ...  False 2024-01-01  New Year's Day
# 13             Central Harlem  ...  False 2024-01-01  New Year's Day
# 14       Central Harlem North  ...  False 2024-01-01  New Year's Day
# ...                       ...  ...    ...        ...             ...
# 2859437    World Trade Center  ...  False 2024-12-25   Christmas Day
# 2859438        Yorkville East  ...  False 2024-12-25   Christmas Day
# 2859439        Yorkville East  ...  False 2024-12-25   Christmas Day
# 2859440        Yorkville West  ...  False 2024-12-25   Christmas Day
# 2859441        Yorkville West  ...  False 2024-12-25   Christmas Day
#
#            type_x     date_y       holiday_y    type_y       date  \
# 10       National 2024-01-01  New Year's Day  National 2024-01-01
# 11       National 2024-01-01  New Year's Day  National 2024-01-01
# 12       National 2024-01-01  New Year's Day  National 2024-01-01
# 13       National 2024-01-01  New Year's Day  National 2024-01-01
# 14       National 2024-01-01  New Year's Day  National 2024-01-01
# ...           ...        ...             ...       ...        ...
# 2859437  National 2024-12-25   Christmas Day  National 2024-12-25
# 2859438  National 2024-12-25   Christmas Day  National 2024-12-25
# 2859439  National 2024-12-25   Christmas Day  National 2024-12-25
# 2859440  National 2024-12-25   Christmas Day  National 2024-12-25
# 2859441  National 2024-12-25   Christmas Day  National 2024-12-25
#
#                 holiday      type
# 10       New Year's Day  National
# 11       New Year's Day  National
# 12       New Year's Day  National
# 13       New Year's Day  National
# 14       New Year's Day  National
# ...                 ...       ...
# 2859437   Christmas Day  National
# 2859438   Christmas Day  National
# 2859439   Christmas Day  National
# 2859440   Christmas Day  National
# 2859441   Christmas Day  National
#
# [116804 rows x 54 columns]
